# %% [markdown]
# ## Formatting the data (air temperature for each month)

# %%
import pandas as pd

# %% [markdown]
# ### Import data in .csv format and delete data before 1996

# %%
df = pd.read_csv('February.txt', sep=";", header=1) 
#source: https://opendata.dwd.de/climate_environment/CDC/regional_averages_DE/monthly/air_temperature_mean/

# %%
df.head()
# Out:
#    Jahr  Monat  Brandenburg/Berlin  Brandenburg  Baden-Wuerttemberg  Bayern  \
# 0  1881      2               -1.00        -1.01                1.33   -0.73
# 1  1882      2                2.06         2.05                0.72   -0.60
# 2  1883      2                1.63         1.62                2.73    0.88
# 3  1884      2                2.89         2.88                2.55    1.19
# 4  1885      2                2.45         2.44                3.55    1.42
#
#    Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 0    0.75                   -2.01          -0.05
# 1    1.44                    2.01           3.03
# 2    2.91                    1.64           3.31
# 3    2.56                    2.78           3.65
# 4    3.31                    2.27           4.05
#
#    Niedersachsen/Hamburg/Bremen  Nordrhein-Westfalen  Rheinland-Pfalz  \
# 0                         -0.07                 1.64             1.45
# ...

# %%
df.columns
# Out:
# Index(['Jahr', 'Monat', 'Brandenburg/Berlin', 'Brandenburg',
#        'Baden-Wuerttemberg', 'Bayern', 'Hessen', 'Mecklenburg-Vorpommern',
#        'Niedersachsen', 'Niedersachsen/Hamburg/Bremen', 'Nordrhein-Westfalen',
#        'Rheinland-Pfalz', 'Schleswig-Holstein', 'Saarland', 'Sachsen',
#        'Sachsen-Anhalt', 'Thueringen/Sachsen-Anhalt', 'Thueringen',
#        'Deutschland', 'Unnamed: 19'],
#       dtype='object')

# %%
df = df.drop(df[df['Jahr']<1996].index)

# %% [markdown]
# ### Merging the columns "Jahr" and "Monat"

# %%
df['Time'] = df['Jahr'].astype(str) + '-' + '0' + df["Monat"].astype(str)
df.rename(columns={'Deutschland': 'Air_Temperature'}, inplace=True)

# %%
df.head()
# Out:
#      Jahr  Monat  Brandenburg/Berlin  Brandenburg  Baden-Wuerttemberg  Bayern  \
# 115  1996      2               -3.13        -3.15               -1.38   -2.69
# 116  1997      2                4.23         4.22                3.83    2.79
# 117  1998      2                5.44         5.42                3.04    2.37
# 118  1999      2                1.05         1.03               -0.69   -1.48
# 119  2000      2                4.11         4.11                3.65    2.80
#
#      Hessen  Mecklenburg-Vorpommern  Niedersachsen  \
# 115   -1.39                   -3.65          -1.99
# 116    4.26                    3.82           5.12
# 117    3.84                    5.31           5.79
# 118    0.51                    0.85           1.80
# 119    3.70                    3.96           4.70
#
#      Niedersachsen/Hamburg/Bremen  ...  Rheinland-Pfalz  Schleswig-Holstein  \
# 115                         -1.99  ...            -0.65               -2.80
# ...

# %% [markdown]
# ### Delete unnecassary columns and change the order

# %%
df.dtypes
# Out:
# Jahr                              int64
# Monat                             int64
# Brandenburg/Berlin              float64
# Brandenburg                     float64
# Baden-Wuerttemberg              float64
# Bayern                          float64
# Hessen                          float64
# Mecklenburg-Vorpommern          float64
# Niedersachsen                   float64
# Niedersachsen/Hamburg/Bremen    float64
# Nordrhein-Westfalen             float64
# Rheinland-Pfalz                 float64
# Schleswig-Holstein              float64
# Saarland                        float64
# Sachsen                         float64
# Sachsen-Anhalt                  float64
# Thueringen/Sachsen-Anhalt       float64
# Thueringen                      float64
# Air_Temperature                 float64
# Unnamed: 19                     float64
# Time                             object
# dtype: object

# %%
columns_to_delete = list(range(0,18))
new_columns_order = ['Time', 'Air_Temperature']

# %%
df = df.drop(df.columns[columns_to_delete], axis=1)
df = df.drop('Unnamed: 19', axis=1)
df = df[new_columns_order]

# %%
df.head()
# Out:
#         Time  Air_Temperature
# 115  1996-02            -2.18
# 116  1997-02             4.10
# 117  1998-02             4.33
# 118  1999-02             0.39
# 119  2000-02             3.87

# %% [markdown]
# ### Saving the data

# %%
df.to_csv('February_air_temperature.csv')
