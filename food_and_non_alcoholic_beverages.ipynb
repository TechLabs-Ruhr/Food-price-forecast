# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("C:\Price Forecasting Datensätze\Sheet1.xlsm")

# %%
df
# Out:
#                TIME 1996-01 Unnamed: 2 1996-02 Unnamed: 4 1996-03 Unnamed: 6  \
# 0           Belgium   65.83        NaN   65.96        NaN   66.42        NaN
# 1          Bulgaria       :        NaN       :        NaN       :        NaN
# 2           Czechia    67.7        NaN    68.1        NaN    68.9        NaN
# 3           Denmark    68.2        NaN    68.4        NaN    68.7        NaN
# 4           Germany    75.7        NaN    76.3        NaN    76.7        NaN
# 5           Estonia   48.18        NaN   50.55        NaN   51.51        NaN
# 6           Ireland      79        NaN    79.3        NaN    79.7        NaN
# 7            Greece   60.18        NaN   60.87        NaN   62.36        NaN
# 8             Spain   63.99        NaN   63.87        NaN    63.8        NaN
# 9            France    72.8        NaN   72.94        NaN   73.55        NaN
# 10          Croatia       :        NaN       :        NaN       :        NaN
# ...

# %%
columns = df.columns
print(columns)
# Out:
# Index(['TIME', '1996-01', 'Unnamed: 2', '1996-02', 'Unnamed: 4', '1996-03',
#        'Unnamed: 6', '1996-04', 'Unnamed: 8', '1996-05',
#        ...
#        'Unnamed: 652', '2023-03', 'Unnamed: 654', '2023-04', 'Unnamed: 656',
#        '2023-05', 'Unnamed: 658', '2023-06', 'Unnamed: 660', '2023-07'],
#       dtype='object', length=662)

# %%
columns_new = columns.tolist()

# %%
un_columns = [i for i in columns_new if i.startswith('Unnamed')]
print(un_columns)
# Out:
# ['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24', 'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32', 'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40', 'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48', 'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56', 'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64', 'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72', 'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80', 'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88', 'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96', 'Unnamed: 98', 'Unnamed: 100', 'Unnamed: 102', 'Unnamed: 104', 'Unnamed: 106', 'Unnamed: 108', 'Unnamed: 110', 'Unnamed: 112', 'Unnamed: 114', 'Unnamed: 116', 'Unnamed: 118', 'Unnamed: 120', 'Unnamed: 122', 'Unnamed: 124', 'Unnamed: 126', 'Unnamed: 128', 'Unnamed: 130', 'Unnamed: 
# ...

# %%
df_new = df.drop(un_columns, axis = 1)
df_new
# Out:
#                TIME 1996-01 1996-02 1996-03 1996-04 1996-05 1996-06 1996-07  \
# 0           Belgium   65.83   65.96   66.42   66.69   67.15   67.09   66.42
# 1          Bulgaria       :       :       :       :       :       :       :
# 2           Czechia    67.7    68.1    68.9    69.6    70.4    71.2    70.2
# 3           Denmark    68.2    68.4    68.7    68.8    69.2    69.4    69.9
# 4           Germany    75.7    76.3    76.7      77    76.8    76.8    76.7
# 5           Estonia   48.18   50.55   51.51   52.44   52.72    52.7   52.57
# 6           Ireland      79    79.3    79.7    80.1    80.5    80.6    80.6
# 7            Greece   60.18   60.87   62.36   63.24   64.11   63.49   61.49
# 8             Spain   63.99   63.87    63.8   64.38   64.83   64.45   64.45
# 9            France    72.8   72.94   73.55    73.5   74.21   73.85   73.65
# 10          Croatia       :       :       :       :       :       :       :
# ...

# %%
df_new.to_csv("Food_and_non_alcoholic_beverages.csv" ,index = False)
